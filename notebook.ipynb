# %% [markdown]
# # Intro
#
# This is a Jupyter Notebook demonsrating GitPod features

# %%
print("hello world")
# Out:
# hello world

# %%
from matplotlib import pyplot as plt

x = [1, 2, 3]
y = [10, 20, 30]
plt.plot(x,y)
